# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_circles
from sklearn.tree import plot_tree

# %%
np.random.seed(42)
x,y = make_circles(n_samples=500,factor=0.1,noise=0.35,random_state=42)
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
abc = AdaBoostClassifier(n_estimators=30)
print(np.mean(cross_val_score(abc,x,y,scoring='accuracy',cv=10)))
abc.fit(x,y)
# Out:
# 0.808
# AdaBoostClassifier(n_estimators=30)

# %%
plt.figure(figsize=(12,6))
plot_decision_regions(x,y,clf=abc)
plt.show()

# %%
abc.estimators_
# Out:
# [DecisionTreeClassifier(max_depth=1, random_state=1962801004),
#  DecisionTreeClassifier(max_depth=1, random_state=547559639),
#  DecisionTreeClassifier(max_depth=1, random_state=446495667),
#  DecisionTreeClassifier(max_depth=1, random_state=1706335927),
#  DecisionTreeClassifier(max_depth=1, random_state=9828366),
#  DecisionTreeClassifier(max_depth=1, random_state=1276873884),
#  DecisionTreeClassifier(max_depth=1, random_state=171200135),
#  DecisionTreeClassifier(max_depth=1, random_state=643890436),
#  DecisionTreeClassifier(max_depth=1, random_state=2088889500),
#  DecisionTreeClassifier(max_depth=1, random_state=984627246),
#  DecisionTreeClassifier(max_depth=1, random_state=1756449091),
#  DecisionTreeClassifier(max_depth=1, random_state=954567499),
#  DecisionTreeClassifier(max_depth=1, random_state=1167724204),
#  DecisionTreeClassifier(max_depth=1, random_state=945049729),
#  DecisionTreeClassifier(max_depth=1, random_state=52411802),
#  DecisionTreeClassifier(max_depth=1, random_state=606224478),
#  DecisionTreeClassifier(max_depth=1, random_state=422808178),
#  DecisionTreeClassifier(max_depth=1, random_state=833002226),
#  DecisionTreeClassifier(max_depth=1, random_state=281356195),
#  DecisionTreeClassifier(max_depth=1, random_state=183500067),
#  DecisionTreeClassifier(max_depth=1, random_state=928482073),
#  DecisionTreeClassifier(max_depth=1, random_state=1081468714),
#  DecisionTreeClassifier(max_depth=1, random_state=425327898),
#  DecisionTreeClassifier(max_depth=1, random_state=1484752964),
#  DecisionTreeClassifier(max_depth=1, random_state=1403590291),
#  DecisionTreeClassifier(max_depth=1, random_state=779956234),
#  DecisionTreeClassifier(max_depth=1, random_state=1971711229),
#  DecisionTreeClassifier(max_depth=1, random_state=1754281801),
#  DecisionTreeClassifier(max_depth=1, random_state=1471130471),
#  DecisionTreeClassifier(max_depth=1, random_state=358165029)]
